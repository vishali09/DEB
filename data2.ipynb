# %% [markdown]
# <a href="https://colab.research.google.com/github/vishali09/DEB/blob/main/data2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data_df = pd.read_csv("bic.csv")

# %%
data_df.head(10000)
# Out:
#       Unnamed: 0   Timestamp   Open   High    Low  Close  Volume_(BTC)  \
# 0              0  1325317920   4.39   4.39   4.39   4.39      0.455581
# 1            478  1325346600   4.39   4.39   4.39   4.39     48.000000
# 2            547  1325350740   4.50   4.57   4.50   4.57     37.862297
# 3            548  1325350800   4.58   4.58   4.58   4.58      9.000000
# 4           1224  1325391360   4.58   4.58   4.58   4.58      1.502000
# ...          ...         ...    ...    ...    ...    ...           ...
# 9995      334294  1345375560   9.92   9.92   9.92   9.92     18.000000
# 9996      334296  1345375680   9.92   9.92   9.92   9.92     20.000000
# 9997      334297  1345375740   9.92   9.92   9.92   9.92     20.000000
# 9998      334298  1345375800   9.92   9.92   9.92   9.92     59.949265
# 9999      334299  1345375860  10.03  10.03  10.03  10.03     15.580957
#
#       Volume_(Currency)  Weighted_Price
# 0              2.000000        4.390000
# ...

# %%
total_rows = data_df.count

# %%
print(total_rows)
# Out:
# <bound method DataFrame.count of         Unnamed: 0   Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 0                0  1325317920    4.39    4.39    4.39    4.39      0.455581
# 1              478  1325346600    4.39    4.39    4.39    4.39     48.000000
# 2              547  1325350740    4.50    4.57    4.50    4.57     37.862297
# 3              548  1325350800    4.58    4.58    4.58    4.58      9.000000
# 4             1224  1325391360    4.58    4.58    4.58    4.58      1.502000
# ...            ...         ...     ...     ...     ...     ...           ...
# 278058      981087  1384183140  348.49  348.50  348.23  348.50     16.525753
# 278059      981088  1384183200  348.60  348.60  348.49  348.49     15.528694
# 278060      981089  1384183260  348.49  348.49  348.21  348.21      5.120900
# 278061      981090  1384183320  348.48  348.48  347.10  347.10     46.973309
# 278062      981091  1384183380  347.10  347.30  346.02  346.02     14.014095
#
# ...

# %%
data_df.loc[1:20]
# Out:
#     Unnamed: 0   Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 1          478  1325346600  4.39  4.39  4.39   4.39     48.000000
# 2          547  1325350740  4.50  4.57  4.50   4.57     37.862297
# 3          548  1325350800  4.58  4.58  4.58   4.58      9.000000
# 4         1224  1325391360  4.58  4.58  4.58   4.58      1.502000
# 5         1896  1325431680  4.84  4.84  4.84   4.84     10.000000
# 6         2333  1325457900  5.00  5.00  5.00   5.00     10.100000
# 7         3612  1325534640  5.00  5.00  5.00   5.00     19.048000
# 8         4553  1325591100  5.32  5.32  5.32   5.32      2.419173
# 9         4710  1325600520  5.14  5.14  5.14   5.14      0.680000
# 10        4742  1325602440  5.26  5.26  5.26   5.26     29.319392
# 11        4780  1325604720  5.29  5.29  5.29   5.29     29.302457
# 12        4878  1325610600  5.29  5.29  5.29   5.29     11.285444
# 13        4882  1325610840  5.14  5.14  5.14   5.14      0.020000
# ...

# %%
data_df.sample(10)
# Out:
#         Unnamed: 0   Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 11445       348137  1346206140   10.90   10.90   10.90   10.90     36.213954
# 218044      902075  1379442420  127.33  127.33  127.33  127.33      0.116500
# 120961      745634  1370055960  128.04  128.04  128.04  128.04      1.000000
# 207112      884454  1378385160  118.69  119.00  118.31  118.31      7.460203
# 98978       718796  1368445680  117.32  117.32  117.32  117.32      3.970000
# 8254        312329  1344057660   10.81   10.81   10.81   10.81      7.000000
# 196431      868799  1377445860  111.46  111.46  111.46  111.46      0.620000
# 14890       391529  1348809660   12.12   12.17   12.12   12.17     28.636579
# 55019       663884  1365150960  139.36  139.36  139.34  139.34      2.918464
# 170481      821590  1374613320   86.89   86.89   86.89   86.89      3.012797
#
#         Volume_(Currency)  Weighted_Price
# 11445          394.732097       10.900000
# ...

# %%
print("setting date")
# Out:
# setting date

# %%
from datetime import datetime

# %%
data_df
# Out:
#         Unnamed: 0   Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 0                0  1325317920    4.39    4.39    4.39    4.39      0.455581
# 1              478  1325346600    4.39    4.39    4.39    4.39     48.000000
# 2              547  1325350740    4.50    4.57    4.50    4.57     37.862297
# 3              548  1325350800    4.58    4.58    4.58    4.58      9.000000
# 4             1224  1325391360    4.58    4.58    4.58    4.58      1.502000
# ...            ...         ...     ...     ...     ...     ...           ...
# 278058      981087  1384183140  348.49  348.50  348.23  348.50     16.525753
# 278059      981088  1384183200  348.60  348.60  348.49  348.49     15.528694
# 278060      981089  1384183260  348.49  348.49  348.21  348.21      5.120900
# 278061      981090  1384183320  348.48  348.48  347.10  347.10     46.973309
# 278062      981091  1384183380  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price
# ...

# %%
print("setting timestamp")
# Out:
# setting timestamp

# %%
data_df['Date'] = pd.to_datetime(data_df['Timestamp'], unit='s')

# %%
data_df['Date']
# Out:
# 0        2011-12-31 07:52:00
# 1        2011-12-31 15:50:00
# 2        2011-12-31 16:59:00
# 3        2011-12-31 17:00:00
# 4        2012-01-01 04:16:00
#                  ...
# 278058   2013-11-11 15:19:00
# 278059   2013-11-11 15:20:00
# 278060   2013-11-11 15:21:00
# 278061   2013-11-11 15:22:00
# 278062   2013-11-11 15:23:00
# Name: Date, Length: 278063, dtype: datetime64[ns]

# %%
data_df.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'Open', 'High', 'Low', 'Close',
#        'Volume_(BTC)', 'Volume_(Currency)', 'Weighted_Price', 'Date'],
#       dtype='object')

# %%
data_df = data_df.reindex(columns=['Date', 'Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)',
       'Volume_(Currency)', 'Weighted_Price'])

# %%
del data_df['Timestamp']

# %%
data_df
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price
# 0                2.000000        4.390000
# ...

# %%
data_df['Year'] = pd.DatetimeIndex(data_df.Date).year
data_df['Month'] = pd.DatetimeIndex(data_df.Date).month
data_df['Day'] = pd.DatetimeIndex(data_df.Date).day
data_df['Weekday'] = pd.DatetimeIndex(data_df.Date).weekday

# %%
data_df
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# ...

# %%
print("Weighted price Analysis")
# Out:
# Weighted price Analysis

# %%
data_df.Weighted_Price.sum()
# Out:
# 30303428.319344062

# %%
data_df.Weighted_Price.count()
# Out:
# 278063

# %%
data_df.Weighted_Price.mean()
# Out:
# 108.98044083298646

# %%
data_df.Weighted_Price.max()
# Out:
# 362.9754773

# %%
data_df.Weighted_Price.min()
# Out:
# 3.8

# %%
data_df.Weighted_Price.min()
# Out:
# 3.8

# %%
print(data_df['Weighted_Price'].isnull().head(20))
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Weighted_Price, dtype: bool

# %%
data_df_clean = data_df.dropna(axis = 0, how = 'any')

# %%
data_df_clean
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
data_df_clean[data_df_clean.Year == 2011][['Weighted_Price']].mean()
# Out:
# Weighted_Price    4.471603
# dtype: float64

# %%
data_df_clean[data_df_clean.Year == 2012][['Weighted_Price']].mean()
# Out:
# Weighted_Price    10.094143
# dtype: float64

# %%
data_df_clean[data_df_clean.Year == 2013][['Weighted_Price']].mean()
# Out:
# Weighted_Price    119.45517
# dtype: float64

# %%
print("Analysation Graph of 2011 to 2013")
# Out:
# Analysation Graph of 2011 to 2013

# %%
plt.plot(data_df_clean.Date, data_df_clean.Weighted_Price);

# %%
data_df_clean_2013 = data_df_clean[data_df_clean.Year == 2013]
data_df_clean_2012 = data_df_clean[data_df_clean.Year == 2012]
data_df_clean_2011 = data_df_clean[data_df_clean.Year == 2011]

# %%
fig, axes = plt.subplots(3, 3, figsize=(40,23))

plt.tight_layout(pad=0)

axes[1,0].plot(data_df_clean_2013.Date, data_df_clean_2013.Weighted_Price);
axes[1,0].set_title('Weighted Price 2013');
axes[1,0].set_xlabel('Date');
axes[1,0].set_ylabel('Price');

axes[1,1].plot(data_df_clean_2012.Date, data_df_clean_2012.Weighted_Price);
axes[1,1].set_title('Weighted Price 2012');
axes[1,1].set_xlabel('Date');
axes[1,1].set_ylabel('Price');

axes[1,2].plot(data_df_clean_2011.Date, data_df_clean_2011.Weighted_Price);
axes[1,2].set_title('Weighted Price 2011');
axes[1,2].set_xlabel('Date');
axes[1,2].set_ylabel('Price');

# %%
data_df_clean.Weighted_Price[(data_df_clean.Year == 2013) & (data_df_clean.Month == 1) & (data_df_clean.Day == 1)].iloc[1]
# Out:
# 13.13

# %%
data_df_clean.Weighted_Price[(data_df_clean.Year == 2013) & (data_df_clean.Month == 11) & (data_df_clean.Day == 1)].iloc[-1]
# Out:
# 202.15

# %%
data_2013 = data_df_clean.Weighted_Price[(data_df_clean.Year == 2013) & (data_df_clean.Month == 11) & (data_df_clean.Day == 1)].iloc[1] - data_df_clean.Weighted_Price[(data_df_clean.Year == 2013) & (data_df_clean.Month == 1) & (data_df_clean.Day == 1)].iloc[1]

# %%
print (int(data_2013))
# Out:
# 190

# %%
print(" Analysis of Bitcoin price difference, between the begining and the end of 2013")
# Out:
#  Analysis of Bitcoin price difference, between the begining and the end of 2013

# %%
analysis_1 = 'Bitcoin price difference, between the begining and the end of 2013, is {}$.'.format(int(data_2013))

# %%
print(analysis_1)
# Out:
# Bitcoin price difference, between the begining and the end of 2013, is 190$.

# %%
data_df_clean
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# ...

# %%
data_df['Open_to_Close'] = data_df.Close - data_df.Open

# %%
print("Open to Close Analysis")
# Out:
# Open to Close Analysis

# %%
data_df
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday  \
# ...

# %%
data_df.Open_to_Close.min()
# Out:
# -65.0

# %%
data_df.Open_to_Close.max()
# Out:
# 49.849999999999994

# %%
data_df.Open_to_Close.mean()
# Out:
# -0.013321225765383742

# %%
data_df_clean
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# ...

# %%
data_df['Open_to_Close'] = data_df.Close - data_df.Open

# %%
data_df_2013 = data_df_clean[data_df_clean.Year == 2013][['Date', 'Open', 'Close', 'Weighted_Price']]

# %%
data_df_2013
# Out:
#                       Date    Open   Close  Weighted_Price
# 26633  2013-01-01 03:52:00   13.24   13.24       13.240000
# 26634  2013-01-01 09:27:00   13.13   13.13       13.130000
# 26635  2013-01-01 09:28:00   13.13   13.13       13.130000
# 26636  2013-01-01 09:38:00   13.12   13.12       13.120000
# 26637  2013-01-01 11:26:00   13.24   13.24       13.240000
# ...                    ...     ...     ...             ...
# 278058 2013-11-11 15:19:00  348.49  348.50      348.465508
# 278059 2013-11-11 15:20:00  348.60  348.49      348.495539
# 278060 2013-11-11 15:21:00  348.49  348.21      348.257332
# 278061 2013-11-11 15:22:00  348.48  347.10      347.852283
# 278062 2013-11-11 15:23:00  347.10  346.02      347.176274
#
# [251430 rows x 4 columns]

# %%
data_df.Open_to_Close
# Out:
# 0         0.00
# 1         0.00
# 2         0.07
# 3         0.00
# 4         0.00
#           ...
# 278058    0.01
# 278059   -0.11
# 278060   -0.28
# 278061   -1.38
# 278062   -1.08
# Name: Open_to_Close, Length: 278063, dtype: float64

# %%
data_df
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday  \
# ...

# %%
data_df_clean
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# ...

# %%
data_highest = data_df_clean.sort_values(by=['Weighted_Price']).tail(1)

# %%
data_highest
# Out:
#                       Date   Open    High    Low   Close  Volume_(BTC)  \
# 275178 2013-11-09 14:38:00  360.4  363.65  360.4  360.41     60.171186
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# 275178         21840.6649      362.975477  2013     11    9        5

# %%
data_highest_price = data_highest.get('Weighted_Price')

# %%
print("Highest weighted price")
# Out:
# Highest weighted price

# %%
data_highest_price
# Out:
# 275178    362.975477
# Name: Weighted_Price, dtype: float64

# %%
data_df_highest_value_date = data_df_clean.Date[(data_df_clean.Weighted_Price > 362)].iloc[1]

# %%
print("Highest Value Date")
# Out:
# Highest Value Date

# %%
data_df_highest_value_date
# Out:
# Timestamp('2013-11-09 14:39:00')

# %%
data_df_highest_value = data_df.Weighted_Price.max()

# %%
int(data_df_highest_value)
# Out:
# 362

# %%
print("The highest weighted price for Bitcoin and its Accurate Time")
# Out:
# The highest weighted price for Bitcoin and its Accurate Time

# %%
analysis_2 = 'The highest weighted price for Bitcoin is {}$ and it occurred on {}.'.format(int(data_df_highest_value), data_df_highest_value_date)

# %%
print(analysis_2)
# Out:
# The highest weighted price for Bitcoin is 362$ and it occurred on 2013-11-09 14:39:00.

# %%
data_df_clean
# Out:
#                       Date    Open    High     Low   Close  Volume_(BTC)  \
# 0      2011-12-31 07:52:00    4.39    4.39    4.39    4.39      0.455581
# 1      2011-12-31 15:50:00    4.39    4.39    4.39    4.39     48.000000
# 2      2011-12-31 16:59:00    4.50    4.57    4.50    4.57     37.862297
# 3      2011-12-31 17:00:00    4.58    4.58    4.58    4.58      9.000000
# 4      2012-01-01 04:16:00    4.58    4.58    4.58    4.58      1.502000
# ...                    ...     ...     ...     ...     ...           ...
# 278058 2013-11-11 15:19:00  348.49  348.50  348.23  348.50     16.525753
# 278059 2013-11-11 15:20:00  348.60  348.60  348.49  348.49     15.528694
# 278060 2013-11-11 15:21:00  348.49  348.49  348.21  348.21      5.120900
# 278061 2013-11-11 15:22:00  348.48  348.48  347.10  347.10     46.973309
# 278062 2013-11-11 15:23:00  347.10  347.30  346.02  346.02     14.014095
#
#         Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# ...

# %%
data_df_clean.sort_values(by=['Weighted_Price']).head(1)
# Out:
#                    Date  Open  High  Low  Close  Volume_(BTC)  \
# 502 2012-01-31 19:05:00   3.8   3.8  3.8    3.8           5.0
#
#      Volume_(Currency)  Weighted_Price  Year  Month  Day  Weekday
# 502               19.0             3.8  2012      1   31        1

# %%
data_df_lowest_value_date = data_df_clean.Date[(data_df_clean.Weighted_Price < 4)].iloc[0]

# %%
print("Lowest Value Date")
# Out:
# Lowest Value Date

# %%
data_df_lowest_value_date
# Out:
# Timestamp('2012-01-27 01:58:00')

# %%
data_df_lowest_value = data_df.Weighted_Price.min()

# %%
print("Lowest Value")
# Out:
# Lowest Value

# %%
data_df_lowest_value
# Out:
# 3.8

# %%
print("The lowest weighted price for Bitcoin and date")
# Out:
# The lowest weighted price for Bitcoin and date

# %%
analysis_3= 'The lowest weighted price for Bitcoin is {}$, and it occurred on {}.'.format(data_df_lowest_value, data_df_lowest_value_date)

# %%
print(analysis_3)
# Out:
# The lowest weighted price for Bitcoin is 3.8$, and it occurred on 2012-01-27 01:58:00.
